# %% [markdown]
# <a href="https://colab.research.google.com/github/Suma183/Movie-Recommender/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pwd
# !ls
# Out:
# /content
# 'archive (2).zip'   archive.zip   sample_data

# %%
# !unzip -q /content/archive.zip -d /content/tmdb
# !ls /content/tmdb
# Out:
# tmdb_5000_credits.csv  tmdb_5000_movies.csv

# %%
import pandas as pd
import numpy as np

movies = pd.read_csv("/content/tmdb/tmdb_5000_movies.csv")
credits = pd.read_csv("/content/tmdb/tmdb_5000_credits.csv")

movies = movies.merge(credits, on="title")
movies = movies[['movie_id','title','overview','genres','keywords','cast','crew']]
movies.dropna(inplace=True)

movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# ...

# %%
import ast

def convert(text):
    return [i['name'] for i in ast.literal_eval(text)]

movies['genres'] = movies['genres'].apply(convert)
movies['keywords'] = movies['keywords'].apply(convert)

def convert_cast(text):
    L = []
    for i, item in enumerate(ast.literal_eval(text)):
        if i < 3:
            L.append(item['name'])
    return L

movies['cast'] = movies['cast'].apply(convert_cast)

def fetch_director(text):
    for i in ast.literal_eval(text):
        if i['job'] == 'Director':
            return [i['name']]
    return []

movies['crew'] = movies['crew'].apply(fetch_director)

movies['overview'] = movies['overview'].apply(lambda x: x.split())

# remove spaces inside names
for col in ['genres','keywords','cast','crew']:
    movies[col] = movies[col].apply(lambda x: [i.replace(" ", "") for i in x])

movies['tags'] = movies['overview'] + movies['genres'] + movies['keywords'] + movies['cast'] + movies['crew']

new_df = movies[['movie_id','title','tags']].copy()
new_df['tags'] = new_df['tags'].apply(lambda x: " ".join(x).lower())

new_df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags
# 0  in the 22nd century, a paraplegic marine is di...
# 1  captain barbossa, long believed to be dead, ha...
# 2  a cryptic message from bond’s past sends him o...
# 3  following the death of district attorney harve...
# 4  john carter is a war-weary, former military ca...

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

cv = CountVectorizer(max_features=5000, stop_words='english')
vectors = cv.fit_transform(new_df['tags']).toarray()

similarity = cosine_similarity(vectors)

# %%
def recommend(movie_title, n=5):
    titles_lower = new_df['title'].str.lower()
    movie_title = movie_title.lower().strip()

    if movie_title not in set(titles_lower):
        close = new_df['title'].head(20).tolist()
        return ["Movie not found. Check spelling from dataset. Example titles:"] + close

    idx = titles_lower[titles_lower == movie_title].index[0]
    scores = list(enumerate(similarity[idx]))
    scores = sorted(scores, key=lambda x: x[1], reverse=True)

    recs = []
    for i in scores[1:n+1]:
        recs.append(new_df.iloc[i[0]]['title'])
    return recs

print(recommend("Avatar"))
# Out:
# ['Titan A.E.', 'Small Soldiers', 'Independence Day', "Ender's Game", 'Aliens vs Predator: Requiem']

# %%
# !pip -q install streamlit pyngrok
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 35.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 26.9 MB/s eta 0:00:00

# %%
import pickle

pickle.dump(new_df, open("movies.pkl", "wb"))
pickle.dump(similarity, open("similarity.pkl", "wb"))

# %%
# %%writefile app.py
import streamlit as st
import pickle

st.set_page_config(page_title="Movie Recommender", page_icon="🎬", layout="centered")

movies = pickle.load(open("movies.pkl", "rb"))
similarity = pickle.load(open("similarity.pkl", "rb"))

st.title("🎬 Movie Recommendation System")
st.write("Select a movie and get 5 similar recommendations (content-based).")

movie_list = movies['title'].values
selected_movie = st.selectbox("Choose a movie", movie_list)

def recommend(movie_title, n=5):
    idx = movies[movies['title'] == movie_title].index[0]
    scores = list(enumerate(similarity[idx]))
    scores = sorted(scores, key=lambda x: x[1], reverse=True)[1:n+1]
    return [movies.iloc[i[0]]['title'] for i in scores]

if st.button("Recommend"):
    recs = recommend(selected_movie)
    st.subheader("Recommended Movies:")
    for r in recs:
        st.write("✅", r)
# Out:
# Writing app.py

# %%
# !ls
# Out:
#  app.py		    archive.zip   sample_data	   tmdb
# 'archive (2).zip'   movies.pkl	  similarity.pkl

# %%
# !pip -q install streamlit
# !wget -q https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64 -O cloudflared
# !chmod +x cloudflared
# !pip -q install streamlit pyngrok

# %%
# !streamlit --version
# !ls -lh cloudflared
# !./cloudflared --version
# Out:
# Streamlit, version 1.53.0
# -rwxr-xr-x 1 root root 40M Nov  7 17:06 cloudflared
# cloudflared version 2025.11.1 (built 2025-11-07-16:59 UTC)

# %%
# !streamlit run app.py --server.port 8501 --server.address 0.0.0.0 > streamlit.log 2>&1 &

# %%
import subprocess, re, time

p = subprocess.Popen(
    ["./cloudflared", "tunnel", "--url", "http://localhost:8501"],
    stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True
)

time.sleep(4)

for _ in range(120):
    line = p.stdout.readline()
    if not line:
        continue
    m = re.search(r"https://[-\w]+\.trycloudflare\.com", line)
    if m:
        print("✅ Public link:", m.group(0))
        break
# Out:
# ✅ Public link: https://readings-kim-hitting-wilderness.trycloudflare.com

# %%
movies.columns
# Out:
# Index(['movie_id', 'title', 'overview', 'genres', 'keywords', 'cast', 'crew',
#        'tags'],
#       dtype='object')

# %%
type(movies), movies.shape
# Out:
# (pandas.core.frame.DataFrame, (4806, 8))

# %%
movies.head(10)
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
# 5       559                              Spider-Man 3
# 6     38757                                   Tangled
# 7     99861                   Avengers: Age of Ultron
# 8       767    Harry Potter and the Half-Blood Prince
# 9    209112        Batman v Superman: Dawn of Justice
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
# ...

# %%
movies.columns
# Out:
# Index(['movie_id', 'title', 'overview', 'genres', 'keywords', 'cast', 'crew',
#        'tags'],
#       dtype='object')

# %%
movies.loc[0]          # first movie
movies.iloc[100]       # 101st movie
# Out:
# movie_id                                                 4922
# title                     The Curious Case of Benjamin Button
# overview    [Tells, the, story, of, Benjamin, Button,, a, ...
# genres           [Fantasy, Drama, Thriller, Mystery, Romance]
# keywords        [diary, navy, funeral, tea, travel, hospital]
# cast                  [CateBlanchett, BradPitt, TildaSwinton]
# crew                                           [DavidFincher]
# tags        [Tells, the, story, of, Benjamin, Button,, a, ...
# Name: 100, dtype: object

# %%
movies[movies['title'].str.contains("harry", case=False, na=False)].head(20)
# Out:
#       movie_id                                      title  \
# 8          767     Harry Potter and the Half-Blood Prince
# 113        675  Harry Potter and the Order of the Phoenix
# 114        674        Harry Potter and the Goblet of Fire
# 191        673   Harry Potter and the Prisoner of Azkaban
# 197        671   Harry Potter and the Philosopher's Stone
# 276        672    Harry Potter and the Chamber of Secrets
# 1623     10152    Dumb and Dumberer: When Harry Met Lloyd
# 2215      2639                       Deconstructing Harry
# 2457       639                    When Harry Met Sally...
# 3335     25941                                Harry Brown
# 4303     11219                     The Trouble with Harry
#
#                                                overview  \
# 8     [As, Harry, begins, his, sixth, year, at, Hogw...
# 113   [Returning, for, his, fifth, year, of, study, ...
# 114   [Harry, starts, his, fourth, year, at, Hogwart...
# ...

# %%
movies.to_csv("movies_preview.csv", index=False)
# !head movies_preview.csv
# Out:
# movie_id,title,overview,genres,keywords,cast,crew,tags
# ...

# %%
# !ls
# Out:
#  app.py		    cloudflared		 sample_data	  tmdb
# 'archive (2).zip'   movies.pkl		 similarity.pkl
#  archive.zip	    movies_preview.csv	 streamlit.log

# %%
# !unzip -q "archive (2).zip" -d telugu_data
# !ls telugu_data
# Out:
# 'indian movies.csv'
